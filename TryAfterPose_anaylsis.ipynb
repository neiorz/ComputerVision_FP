# %%
# !pip install ultralytics

# %%
# !git clone https://github.com/neiorz/ComputerVision_FP.git
# Out:
# fatal: destination path 'ComputerVision_FP' already exists and is not an empty directory.

# %%
# %cd ComputerVision_FP/
# Out:
# /content/ComputerVision_FP

# %%
# !ls
# Out:
# analyze_and_annotate_video.py  pose_predict.py
# dataset			       pose_valid.py
# LICENSE			       __pycache__
# Makefile		       README.md
# output			       requirements.txt
# pose_analysis.py	       TryingPose_predict.ipynb
# pose_custom_data_train.py      utils.py
# pose_custom_data_tune.py       yolov8n-pose.pt
# pose_fusion_predict.py

# %%
from google.colab import drive
drive.mount('/content/drive')
#save a video to try on our drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python pose_predict.py --model yolov8n-pose.pt --source /content/drive/MyDrive/NTI-ComputerVision/YOLOv8_HumanPose/videos/3943396-hd_1920_1080_30fps.mp4 --is_video --save-img
# Out:
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# 0: 384x640 3 persons, 175.2ms
# Speed: 6.9ms preprocess, 175.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# 0: 384x640 3 persons, 126.9ms
# Speed: 3.7ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# 0: 384x640 3 persons, 94.9ms
# Speed: 4.2ms preprocess, 94.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# 0: 384x640 3 persons, 97.6ms
# Speed: 3.0ms preprocess, 97.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# ...
